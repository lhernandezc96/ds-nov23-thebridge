# %%
from roboflow import Roboflow
rf = Roboflow(api_key="VqhZSFCeIYbblZepHCXT")
project = rf.workspace("joseph-nelson").project("thermal-dogs-and-people")
dataset = project.version(1).download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Thermal-Dogs-and-People-1 in coco:: 100%|██████████| 208/208 [00:00<00:00, 2714.77it/s]

# %%
# %pip install streamlit bs4 plotly seaborn
# Out:
# ...
#   WARNING: The script watchmedo.exe is installed in 'c:\Users\lache\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\lache\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema.exe is installed in 'c:\Users\lache\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'c:\Users\lache\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
# ...
