# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página en la cual se encuentran alquileres de pisos en Barcelona

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      -------------------------------------- 143.0/143.0 kB 4.3 MB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.4-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Downloading lxml-4.9.4-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 991.0 kB/s eta 0:00:04
#    -- ------------------------------------- 0.2/3.8 MB 2.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.5/3.8 MB 3.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.9/3.8 MB 5.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/3.8 MB 6.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.9/3.8 MB 7.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 7.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.8/3.8 MB 7.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.3/3.8 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.0 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\lache\appdata\local\programs\python\python311\lib\site-packages (2.20.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lache\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\lache\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\lache\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lache\appdata\local\programs\python\python311\lib\site-packages (from requests) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.yaencontre.com/alquiler/pisos/barcelona"
response = requests.get(url)

# %% [markdown]
# Cómo saber si se guardo correctamente el sitio web?

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!doctype html>\n    <html lang="es" class="notranslate page-results variantContainer withBreadcrumb" translate="no">\n      <head>\n        \n        <title data-rh="true">Pisos y viviendas en alquiler en Barcelona \xc2\xb7 5.347 pisos y viviendas disponibles - yaencontre</title>\n        <meta data-rh="true" name="title" content="Pisos y viviendas en alquiler en Barcelona \xc2\xb7 5.347 pisos y viviendas disponibles - yaencontre"/><meta data-rh="true" name="description" content="5.347 Pisos y viviendas en alquiler en Barcelona. Anuncios de pisos y viviendas de particulares y agencias inmobiliarias. \xc2\xa1Encontrar\xc3\xa1s lo que est\xc3\xa1s buscando!"/><meta data-rh="true" name="robots" content="index, follow"/><meta data-rh="true" name="language" content="es"/>\n        <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" /><meta name="theme-color" content="#e5005a" /><meta http-equiv="content-type" content="text/html; charset=UTF-8" /><meta http-equiv="x-ua-compatible" content="IE=EDGE" /><meta name="google-play-app" content="app-id=com.yaencontre.vivienda" /><meta name="twitter:site" content="@yaencontre" /><meta name="apple-mobile-web-app-capable" content="yes" /><meta name="apple-mobile-web-app-title" content="yaencontre" /><meta name="apple-mobile-web-app-status-bar-style" content="default" /><meta name="mobile-web-app-capable" content="yes" /><meta name="application-name" content="yaencontre" /><meta name="og:site_name" content="yaencontre" /><meta name="google" content="notranslate" /><meta name="format-detection" content="telephone=no" />\n        <link rel="dns-prefetch" href="https://media.yaencontre.com" /><link rel="dns-prefetch" href="https://www.googletagmanager.com" /><link rel="dns-prefetch" href="https://assets.adobedtm.com" /><link rel="dns-prefetch" href="https://sdk.privacy-center.org" />\n        <link data-rh="true" rel="canonical" href="https://www.yaencontre.com/alquiler/pisos/barcelona"/><link data-rh="true" rel="next" href="https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2"/><link data-rh="true" rel="alternate" href="https://www.yaencontre.com/alquiler/pisos/barcelona" hreflang="es"/><link data-rh="true" rel="alternate" href="https://ca.yaencontre.com/lloguer/pisos/barcelona" hreflang="ca"/><link data-rh="true" rel="preload" as="image" href="https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg" media imagesrcset="https://media.yaencontre.com/img/photo/w630/29126/29126-45082523-1086007577.jpg.webp 2x, https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg.webp"/>\n        <link rel="shortcut icon" href="/favicon.ico" /><link rel="apple-touch-icon" href="/rsc/images/icon-60.e01e60.png" /><link rel="apple-touch-icon-precomposed" href="/rsc/images/icon-60.e01e60.png" /><link rel="apple-touch-icon" sizes="76x76" href="/rsc/images/icon-76.3ac59c.png" /><link rel="apple-touch-icon-precomposed" sizes="76x76" href="/rsc/images/icon-76.3ac59c.png" /><link rel="apple-touch-icon" sizes="120x120" href="/rsc/images/icon-120.4696a2.png" /><link rel="apple-touch-icon-precomposed" sizes="120x120" href="/rsc/images/icon-120.4696a2.png" /><link rel="apple-touch-icon" sizes="152x152" href="/rsc/images/icon-152.206459.png" /><link rel="apple-touch-icon-precomposed" sizes="152x152" href="/rsc/images/icon-152.206459.png" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/montserrat-regular-webfont.6fd836.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/Nexa_XBold-webfont.72163f.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/yaencontre-icons.0a4859.woff2" /><link rel="preload" as="font" crossorigin="anonymous" type="font/woff2" href="/rsc/fonts/montserrat-semibold-webfont.66fd23.woff2" />\n        <link data-chunk="footer" rel="preload" as="styl ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los pisos de Barcelona, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html)

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los alquileres de Barcelona)
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="notranslate page-results variantContainer withBreadcrumb" lang="es" translate="no">
# <head>
# <title data-rh="true">Pisos y viviendas en alquiler en Barcelona · 5.347 pisos y viviendas disponibles - yaencontre</title>
# <meta content="Pisos y viviendas en alquiler en Barcelona · 5.347 pisos y viviendas disponibles - yaencontre" data-rh="true" name="title"/><meta content="5.347 Pisos y viviendas en alquiler en Barcelona. Anuncios de pisos y viviendas de particulares y agencias inmobiliarias. ¡Encontrarás lo que estás buscando!" data-rh="true" name="description"/><meta content="index, follow" data-rh="true" name="robots"/><meta content="es" data-rh="true" name="language"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><meta content="#e5005a" name="theme-color"/><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="IE=EDGE" http-equiv="x-ua-compatible"/><meta content="app-id=com.yaencontre.vivienda" name="google-play-app"/><meta content="@yaencontre" name="twitter:site"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="yaencontre" name="apple-mobile-web-app-title"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yaencontre" name="application-name"/><meta content="yaencontre" name="og:site_name"/><meta content="notranslate" name="google"/><meta content="telephone=no" name="format-detection"/>
# <link href="https://media.yaencontre.com" rel="dns-prefetch"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://assets.adobedtm.com" rel="dns-prefetch"/><link href="https://sdk.privacy-center.org" rel="dns-prefetch"/>
# <link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona" rel="canonical"/><link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2" rel="next"/><link data-rh="true" href="https://www.yaencontre.com/alquiler/pisos/barcelona" hreflang="es" rel="alternate"/><link data-rh="true" href="https://ca.yaencontre.com/lloguer/pisos/barcelona" hreflang="ca" rel="alternate"/><link as="image" data-rh="true" href="https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg" imagesrcset="https://media.yaencontre.com/img/photo/w630/29126/29126-45082523-1086007577.jpg.webp 2x, https://media.yaencontre.com/img/photo/w380/29126/29126-45082523-1086007577.jpg.webp" media="" rel="preload"/>
# <link href="/favicon.ico" rel="shortcut icon"/><link href="/rsc/images/icon-60.e01e60.png" rel="apple-touch-icon"/><link href="/rsc/images/icon-60.e01e60.png" rel="apple-touch-icon-precomposed"/><link href="/rsc/images/icon-76.3ac59c.png" rel="apple-touch-icon" sizes="76x76"/><link href="/rsc/images/icon-76.3ac59c.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="/rsc/images/icon-120.4696a2.png" rel="apple-touch-icon" sizes="120x120"/><link href="/rsc/images/icon-120.4696a2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="/rsc/images/icon-152.206459.png" rel="apple-touch-icon" sizes="152x152"/><link href="/rsc/images/icon-152.206459.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/montserrat-regular-webfont.6fd836.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/Nexa_XBold-webfont.72163f.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/yaencontre-icons.0a4859.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="/rsc/fonts/montserrat-semibold-webfont.66fd23.woff2" rel="preload" type="font/woff2"/>
# <link as="style" data-chunk="footer" href="/rsc/css/9348.eb6be4.css" rel="preload"/>
# <link as="style" data-chunk="results-low" href="/rsc/css/1775.d28d0a.css" rel="preload"/>
# <link as="style" data-chunk="clickEngine" href="/rsc/css/6485.4d7d34.css" rel="preload"/>
# <link as="style" data-chunk="thinElementsList" href="/rsc/css/9608.004da1.css" rel="preload"/>
# <link as="style" data-chunk="thinElementsList" href="/rsc/css/7537.3562e1.css" rel="preload"/>
# <link as="style" data-chunk="results-options" href="/rsc/css/5581.7875d4.css" rel="preload"/>
# <link as="style" data-chunk="results" href="/rsc/css/18.41c5a2.css" rel="preload"/>
# <link as="style" data-chunk="app" href="/rsc/css/app.148bfc.css" rel="preload"/>
# <link data-chunk="app" href="/rsc/css/app.148bfc.css" rel="stylesheet"/>
# <link data-chunk="results" href="/rsc/css/18.41c5a2.css" rel="stylesheet"/>
# <link data-chunk="results-options" href="/rsc/css/5581.7875d4.css" rel="stylesheet"/>
# <link data-chunk="thinElementsList" href="/rsc/css/7537.3562e1.css" rel="stylesheet"/>
# <link data-chunk="thinElementsList" href="/rsc/css/9608.004da1.css" rel="stylesheet"/>
# <link data-chunk="clickEngine" href="/rsc/css/6485.4d7d34.css" rel="stylesheet"/>
# <link data-chunk="results-low" href="/rsc/css/1775.d28d0a.css" rel="stylesheet"/>
# <link data-chunk="footer" href="/rsc/css/9348.eb6be4.css" rel="stylesheet"/>
# </head>
# <body>
# <div id="app"><nav class="Nav"><div class="container"><a class="icon-logo" href="/"></a><a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a><a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a><div class="alertFeed-wrapper mr-sm"><div class="alertFeed-button pointer icon-alert"><span class="counter">0</span></div></div><div class="Login icon-user pointer"><span class="d-none--tablet">Accede</span></div></div></nav><div class="Results"><div class="headerNav pt-0"><div class="controlsBox pt-0"><div class="flex align-center"><h1 class="d-ellipsis title-results">5.347 Pisos y viviendas en alquiler en Barcelona</h1></div></div></div><div class="headerBreadcrumb"><div class="controlsBox pt-0"><ul class="newBreadcrumb"><li><a class="d-none--tablet" href="/">yaencontre</a></li><li><a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a></li><li><a class="link" href="/alquiler/pisos/barcelones">Barcelonès</a></li><li><div class="breadcrumb-level"><div class="pos-rel"><div class="breadcrumb-level__title last-item icon-arrow-down-after"><p class="d-ellipsis">Barcelona</p></div><div class="breadcrumb__toogle-content d-none"><ul><li class="flex flex-nowrap mb-xs d-none--desktop"><span class="link d-ellipsis">Barcelona (provincia)</span><span class="ml-sm">6.993</span></li><li class="flex flex-nowrap mb-xs d-none--desktop"><span class="link d-ellipsis">Barcelonès</span><span class="ml-sm">5.647</span></li><li class="d-block"><ul class="final-container"><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/badalona">Badalona</a><span class="ml-sm">87</span></div></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis toogle-item__title--selected breadcrumb-selected" href="/alquiler/pisos/barcelona">Barcelona</a><span class="ml-sm">5.360</span></div><ul class="inner-items"><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-ciutat-vella">Ciutat Vella</a><span class="ml-sm">1.268</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-eixample">Eixample</a><span class="ml-sm">1.634</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-gracia">Gràcia</a><span class="ml-sm">394</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-horta-guinardo">Horta - Guinardó</a><span class="ml-sm">158</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-les-corts">Les Corts</a><span class="ml-sm">215</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-nou-barris">Nou Barris</a><span class="ml-sm">46</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-andreu">Sant Andreu</a><span class="ml-sm">59</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-marti">Sant Martí</a><span class="ml-sm">503</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sants-montjuic">Sants - Montjuïc</a><span class="ml-sm">332</span></li><li class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sarria-sant-gervasi">Sarrià - Sant Gervasi</a><span class="ml-sm">750</span></li></ul></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/hospitalet-de-llobregat-l">Hospitalet de Llobregat, L´</a><span class="ml-sm">165</span></div></li><li class="toogle-item"><div class="flex flex-nowrap"><a class="link d-ellipsis" href="/alquiler/pisos/sant-adri ...
# PERFECTO PARA TRABAJADORES DE EMPRESAS O ESTUDIANTES!
# Alojamiento de alquiler mensual, consultar las condiciones previamente.
# Ideal para estudiantes Erasmus, trabajadores de aeropuerto, cerca del HOSPITAL SANT PAU, MATERNITAT, CLINIC, y ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 88 45</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/finques-reina-real-estate-29126" title="Finques Reina Real Estate"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96352122" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.190 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">80 m²</span></div></div><p class="description">APARTAMENTO DE ALQUILER TEMPORAL.
# PERFECTO PARA TRABAJADORES DE EMPRESAS O ESTUDIANTES!
# Alojamiento de alquiler mensual, consultar las condiciones previamente.
# El apartamento es una planta baja completamente reformada y a estrenar dividida en dos plantas. La p...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 88 45</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-u8178150_37224251" title="Piso en calle Formatgeria, El Gòtic, Barcelona">Piso en calle Formatgeria, El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">825 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">45 m²</span></div></div><p class="description">Piso reformado, amueblado y con electrodomésticos, con una habitación doble independiente con dos armarios, salón comedor exterior, cocina y cuarto de baño, situado en la zona del Passeig del Born y Santa Maria del Mar, muy cerca de las playas de la Barcelonet...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">Llamar</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="banner-wrapper with-title banner-ad d-none" id="box_sas_91212"><div><div class="publi-text">Publicidad</div><div class="results-roba1" id="sas_91212"></div></div></div><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60288-99803422" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.200 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">109 m²</span></div></div><p class="description">Bienvenido a XRP Penthouse, un ático dúplex verdaderamente vibrante y especial con terraza privada en el corazón del Barrio Gótico. El apartamento está ubicado en el sexto piso (con ascensor) y disfruta de una gran cantidad de sol, luz natural y vistas.
#
# En el...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 51 22</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/bcn-advisors-60085" title="Bcn Advisors"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60085-100265982" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">150 m²</span></div></div><p class="description">Esta vivienda reformada con acabados de lujo se encuentra en una de las calles principales del mítico barrio del Born de Barcelona: una zona con mucho encanto que invita a perderse por sus calles medievales, repletas de comercios, restauración y, a su vez, bie...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 92 14</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-67077-100856122" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.341 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">130 m²</span></div></div><p class="description">Estamos disponibles todos los días de la semana. Si lo prefieres, puedes contactarnos directamente por WhatsApp en el
#
# Situado a los pies del Tibidabo, encontramos este fantástico complejo residencial con piscina comunitaria y amplia zona ajardinada con parqu...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 84 87</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="banner-wrapper with-title banner-ad d-none" id="box_sas_91213"><div><div class="publi-text">Publicidad</div><div class="results-roba2" id="sas_91213"></div></div></div><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-56966-103134675" title="Piso en Sant Gervasi - La Bonanova, Barcelona">Piso en Sant Gervasi - La Bonanova, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.763 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">102 m²</span></div></div><p class="description">Increíble piso en la zona alta de Barcelona.
#
# Está ubicado en la zona alta de Barcelona, en una prestigiosa comunidad. La comunidad cuenta con vigilancia 24h y conserjería 24h. También cuenta con piscina exterior, zonas verdes y zona de parque infantil.
# El pis...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 60 98</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60134-102291997" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">7.500 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">221 m²</span></div></div><p class="description">En pleno Paseo de Gracia, con las mejores vistas a la Casa Batlló, gran piso reformado de 221 m2, IDEAL COMO VIVIENDA O COMO DESPACHO PROFESIONAL. Se ofrece en ALQUILER y en VENTA.
#
# Este Este apartamento está totalmente reformado y se compone de: gran salón-co...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 24 95</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/bourgeois-fincas-56391" title="Bourgeois Fincas"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-56391-102890997" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.310 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">110 m²</span></div></div><p class="description">Esta preciosa vivienda de 3 dormitorios esta ubicada en una de las mejores zonas de Barcelona. En frente de la misma hay un inmejorable parque 'Turó Park' y la zona tiene comercios, supermercados, hostelería, etc.
# El piso ha sido totalmente reformado y tiene ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 50 82</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60789-103076693" title="Piso en El Camp de l'Arpa del Clot, Barcelona">Piso en El Camp de l'Arpa del Clot, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.250 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">85 m²</span></div></div><p class="description">Piso en alquiler cerca de sagrada Familia - Corta de 11 MESES
#
# Este bonito apartamento de 95m2, se encuentra en una zona inmejorable de la ciudad de Barcelona. En plena calle de Provença, a escasos minutos de las paradas de metro Encants, Camp de l'Arpa, Glori...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 03 36</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class="notification-results listBox"><div class="content-title pt-md"><p class="h3 notification-results__title icon-bell mb-0">¿Quieres que te avisemos de las últimas novedades de pisos y viviendas en alquiler en Barcelona?</p></div><form class="form flex" novalidate=""><div class="content-form"><fieldset class="form-fieldset"><div class="form-group field-email"><input class="form-control" id="notification-last-changes_email" name="email" placeholder="Tu e-mail" required="" type="email" value=""/></div></fieldset></div><div class="content-button"><button class="btn button"><span class="label-button">Recibir alertas</span></button></div></form><div class="content-legal"><div><div class="box-readmore" style="overflow-y:hidden;max-height:85px"><div class="robots-nocontent robots-noindex legalAdvice readMoreText" data-nosnippet="true" style="transform:translateY(-0px);color:transparent;background-image:linear-gradient(
#     #737373 42.5px,
#     #ffffff 85px
#   );-webkit-background-clip:text"><noindex>yaencontre (idealista) te informa que tus datos personales serán utilizados para crear tu Área Personal, dónde podrás gestionar tus avisos y enviarte información de nuestros productos según tus preferencias. Podrás ejercer tus derechos de protección de datos según la siguiente <span class="link">política de privacidad</span>.</noindex></div></div><div class="lower-container"><div class="text-center pointer icon-arrow-down-after d-none--desktop"></div></div></div></div></div><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/casamona-international-real-estate-49875" title="Casamona (International Real Estate)"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-49875-103023735" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">1.850 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">63 m²</span></div></div><p class="description">¡DISPONIBLE A PARTIR DE ENERO PARA ALQUILERES TEMPORALES ENTRE 3 - 11 MESES!
#
# Ático totalmente equipado en Via Laietana. 58 m2 totalmente reformados con una espectacular terraza privada con vistas a toda la ciudad y al Barrio Gótico. La terraza cuenta con mesa...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 62 41</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-57129-101666372" title="Piso en L'Antiga Esquerra de l'Eixample, Barcelona">Piso en L'Antiga Esquerra de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.300 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">4 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">115 m²</span></div></div><p class="description">Piso de 2004 totalmente amueblado y equipado en L'antiga esquerra de l'eixample.
#
# La vivienda consta de 115 metros construidos y 99 metros útiles.
#
# 4 habitaciones (dos dobles y 2 individuales), todas ellas con armarios empotrados. Una de ellas en suite con bañ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 60 20</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60293-99813022" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">4.550 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">2 habs.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">63 m²</span></div></div><p class="description">Vivienda de lujo amueblada por estrenar al lado de Paseo de Gracia
#
# A un paso de Paseo de Gracia, en una ubicación privilegiada, nos encontramos con un lujoso y moderno apartamento nuevo por estrenar decorado por el reconocido interiorista Jaime Beriestain.
#
# L...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 40 47</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/selekta-properties-48918" title="Selekta Properties"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-48918-101242262" title="Piso en La Dreta de l'Eixample, Barcelona">Piso en La Dreta de l'Eixample, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">1 hab.</span></div><div class="icon-bath"><span class="">1 baño</span></div><div class="icon-meter"><span class="">50 m²</span></div></div><p class="description">El apartamento de 1 dormitorio doble y 1 baño, se encuentra ubicado en la zona de Eixample en Barcelona, una de las zonas más céntricas y populares de la ciudad. La propiedad cuenta con una sala de estar-comedor, equipada con un cómodo sofá para descansar desp...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 80 46</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158804" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">123 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distrib
# ución y amplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standing.
#
# En este caso, un f...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158914" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.850 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">123 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 123 m2, situado en una segunda altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, el recibidor nos d
# a paso a un gran espacio con dos ambientes diferenciados, una cocina americana equipada con horno, microondas ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158532" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.650 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">91 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 91m2, situado en una tercera altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, el recibidor nos da paso a un gran espacio con dos ambientes diferenciados, una cocina office independiente equipada con horno,
# mi...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158642" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.500 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">91 m²</span></div></div><p class="description">Fantástico piso de obra nueva de 91m2, situado en una tercera altura con mucha luz natural, nuevo a estrenar. Al entrar al piso, e
# l recibidor nos da paso a un gran espacio con dos ambientes diferenciados, una cocina office independiente equipada con horno, mi...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158851" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">122 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distribución y amplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standi
# ng.
#
# En este caso, un f...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158745" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.750 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">119 m²</span></div></div><p class="description">Edificio de 44 exclusivas viviendas de obra nueva, con detalles de alto standing. Pisos de 2 o 3 dormitorios con magnifica distribución,
# muy amplios, con luz natural y una variedad de terrazas, balcones y/o patios.
#
# En este caso, presentamos este fantástico p...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102158609" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.950 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">99 m²</span></div></div><p class="description">Nos encontramos ante un edificio con 44 exclusivas viviendas de obra nueva, a estrenar, de 2 y 3 dormitorios con una magnifica distribución y a
# mplitud, luz natural, y grandes terrazas, cuidando cada detalle y con acabados de alto standing.
# El edificio, de 5 ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 97 93</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/habita-barcelona-54965" title="Habita Barcelona"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54965-102163439" title="Piso en Sant Gervasi - Galvany, Barcelona">Piso en Sant Gervasi - Galvany, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.550 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">97 m²</span></div></div><p class="description">Fantástico piso de obra nueva
# ...
#
# Ubicado en Diagonal Mar, esta notable propiedad cuenta con vistas despejadas del reluciente mar por un lado y las ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-94457604" title="Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">10.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">200 m²</span></div></div><p class="description">Este maravilloso y exclusivo ático con una gran terraza e impresionantes vistas al mar está ubicado en el prestigioso Paseo García Faria.
#
# Con una increíble piscina privada y vistas directas al mar, este ático es perfecto para aquellos que buscan una experien...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><span class="invisible"></span><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-99196120" title="Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">7.000 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">3 baños</span></div><div class="icon-meter"><span class="">210 m²</span></div></div><p class="description">Este impresionante ático de primera línea con piscina privada y vistas directas al mar es la personificación de la comodidad, la privacidad y la exclusividad! Ubicado en el prestigioso Paseo García Faria, este maravilloso y exclusivo ático cuenta con una gran ...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><article class="ThinPropertyList property-info pointer pos-rel"><div class="image prevent pos-rel"><div class="image-lazyloading"><div class="no-image-placeholder"></div></div></div><div class="content"><div class="prevent d-only-mobile single-contact btn-rounded icon-mail btn pointer"></div><a class="logo-inmo prevent" href="/inmobiliarias/royal-ground-54754" title="ROYAL GROUND"><span class="image-lazyloading"></span></a><h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-54754-100763886" title="Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona">Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">3.800 €</span></div></h3><div class="iconGroup"><div class="icon-room"><span class="">3 habs.</span></div><div class="icon-bath"><span class="">2 baños</span></div><div class="icon-meter"><span class="">130 m²</span></div></div><p class="description">Este notable apartamento está situado en el prestigioso complejo Illa de La Llum, diseñado por los renombrados arquitectos LLuís Clotet e Ignacio Paricio, que fue galardonado con el Premio Construmat a la Innovación Tecnológica en la categoría de Edificación e...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon ...
#
# Situado en el prestigioso Paseo...</p><div class="actions pos-rel"><div class="prevent contact-bottom"><div class="icon-phone-2 btn"><span class="d-only-tablet">93 617 30 40</span><span class="d-only-desktop">Ver teléfono</span></div><button class="icon-mail pointer btn">Contactar</button></div><div class="header-info__action-icons prevent"><div class="icon-alert d-only-desktop d-none-de-medium-desktop d-none-fr-medium-desktop d-none-it-medium-desktop pointer"><span class="">Aviso bajada</span></div><div class="icon-save pointer"><span class="">Guardar</span></div></div></div></div></article><div class=""><div class="mt-lg"><h2 class="h3">Inmobiliarias en Barcelona</h2><div class="carousel-container no-gutters-by-tablet"><div class="carousel-items" style="transform:translateX(0px);width:3285px"><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/ukio-spain-s-l-56196" title="Ukio Spain S.L.">Ukio Spain S.L.</a></h3><p class="real-estate-panel__counter d-ellipsis-de">347 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/shbarcelona-46589" title="ShBarcelona">ShBarcelona</a></h3><p class="real-estate-panel__counter d-ellipsis-de">345 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/engel-a-volkers-barcelona-51945" title="Engel &amp; Völkers Barcelona">Engel &amp; Völkers Barcelona</a></h3><p class="real-estate-panel__counter d-ellipsis-de">279 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/homelike-60247" title="Homelike">Homelike</a></h3><p class="real-estate-panel__counter d-ellipsis-de">217 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/aproperties-real-estate-barcelona-60293" title="aProperties Real Estate Barcelona">aProperties Real Estate Barcelona</a></h3><p class="real-estate-panel__counter d-ellipsis-de">152 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/atemporal-55533" title="aTemporal">aTemporal</a></h3><p class="real-estate-panel__counter d-ellipsis-de">145 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/blueground-barcelona-62292" title="BLUEGROUND BARCELONA">BLUEGROUND BARCELONA</a></h3><p class="real-estate-panel__counter d-ellipsis-de">100 viviendas</p></div><span class="button">Ver</span></div><div class="real-estate-panel"><div class="real-estate-panel__img"><span class="image-lazyloading"></span></div><div class="real-estate-panel__content"><h3><a class="real-estate-panel__title prevent" href="/inmobiliarias/uniplaces-69125" title="Uniplaces">Uniplaces</a></h3><p class="real-estate-panel__counter  ...
# <script id="ssr_initialState">
#       window.__INITIAL_STATE__ = JSON.parse("{\"agencyList\":{\"isFetching\":false,\"currentPageItems\":{\"byId\":{},\"sortedItems\":[]}},\"results\":{\"isFetching\":false,\"currentPageItems\":{\"byId\":{\"jht::real-estate::29126-96822843\":{\"item\":{\"images\":[{\"slug\":\"29126/29126-45082523-1086007577.jpg\"},{\"slug\":\"29126/29126-45082523-1086007578.jpg\"},{\"slug\":\"29126/29126-45082523-1086007579.jpg\"},{\"slug\":\"29126/29126-45082523-1086007580.jpg\"},{\"slug\":\"29126/29126-45082523-1086007581.jpg\"},{\"slug\":\"29126/29126-45082523-1086007582.jpg\"},{\"slug\":\"29126/29126-45082523-1086007583.jpg\"},{\"slug\":\"29126/29126-45082523-1086007584.jpg\"},{\"slug\":\"29126/29126-45082523-1086007585.jpg\"},{\"slug\":\"29126/29126-45082523-1086007586.jpg\"},{\"slug\":\"29126/29126-45082523-1086007587.jpg\"},{\"slug\":\"29126/29126-45082523-1086007588.jpg\"},{\"slug\":\"29126/29126-45082523-1086007589.jpg\"},{\"slug\":\"29126/29126-45082523-1086007590.jpg\"},{\"slug\":\"29126/29126
#       window.JHT = JSON.parse(atob('...'));
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[9647,5649,4158,5954,18,5581,1575,2942,5112,9528,9608,6485,3146]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["results","results-options","thinElementsList","clickEngine","lang-es"]}</script>
# <script async="" data-chunk="app" src="/rsc/js/runtime~app.52c337.js"></script>
# <script async="" data-chunk="app" src="/rsc/js/693.a5d147.js"></script>
# <script async="" data-chunk="app" src="/rsc/js/app.ecfaee.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/9647.cd4865.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/5649.c1b388.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/4158.e8b044.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/5954.611940.js"></script>
# <script async="" data-chunk="results" src="/rsc/js/results.db5012.js"></script>
# <script async="" data-chunk="results-options" src="/rsc/js/results-options.ca80a3.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/1575.69ceaf.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/2942.36861c.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/5112.228d9a.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/9528.f35daf.js"></script>
# <script async="" data-chunk="thinElementsList" src="/rsc/js/thinElementsList.aaa169.js"></script>
# <script async="" data-chunk="clickEngine" src="/rsc/js/clickEngine.285929.js"></script>
# <script async="" data-chunk="lang-es" src="/rsc/js/lang-es.9611dd.js"></script>
# </body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title data-rh="true">Pisos y viviendas en alquiler en Barcelona · 5.347 pisos y viviendas disponibles - yaencontre</title>

# %%
soup.h1
# Out:
# <h1 class="d-ellipsis title-results">5.347 Pisos y viviendas en alquiler en Barcelona</h1>

# %% [markdown]
# Eliminamos las etiquetas

# %%
soup.h1.get_text()
# Out:
# '5.347 Pisos y viviendas en alquiler en Barcelona'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
#Si en inspeccionar, hacemos Ctrl+F y buscamos <a>, encontramos la primera etiqueta a
soup.a
# Out:
# <a class="icon-logo" href="/"></a>

# %%
soup.a["href"]  #Son lo mismo
soup.a.get("href")
# Out:
# '/'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
soup.h1
print(soup.h1)
print("Utilizando método .find()")
soup.find("h1")
# Out:
# Sin utilizar método .find()
# <h1 class="d-ellipsis title-results">5.347 Pisos y viviendas en alquiler en Barcelona</h1>
# Utilizando método .find()
# <h1 class="d-ellipsis title-results">5.347 Pisos y viviendas en alquiler en Barcelona</h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all("a")
# Out:
# [<a class="icon-logo" href="/"></a>,
#  <a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a>,
#  <a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>,
#  <a class="d-none--tablet" href="/">yaencontre</a>,
#  <a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a>,
#  <a class="link" href="/alquiler/pisos/barcelones">Barcelonès</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/badalona">Badalona</a>,
#  <a class="link d-ellipsis toogle-item__title--selected breadcrumb-selected" href="/alquiler/pisos/barcelona">Barcelona</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-ciutat-vella">Ciutat Vella</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-eixample">Eixample</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-gracia">Gràcia</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-horta-guinardo">Horta - Guinardó</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-les-corts">Les Corts</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-nou-barris">Nou Barris</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-andreu">Sant Andreu</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sant-marti">Sant Martí</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sants-montjuic">Sants - Montjuïc</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/barcelona/distrito-sarria-sant-gervasi">Sarrià - Sant Gervasi</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos/hospitalet-de-llobregat-l">Hospitalet de Llobregat, L´</a>,
#  <a class="link d-ellipsis" href="/alquiler/pisos
a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/blueground-barcelona-62292" title="BLUEGROUND BARCELONA">BLUEGROUND BARCELONA</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/uniplaces-69125" title="Uniplaces">Uniplaces</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/my-space-barcelona-60336" title="My Space Barcelona">My Space Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/all4flat-51565" title="ALL4FLAT">ALL4FLAT</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/area-casa-50899" title="Area Casa">Area Casa</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/home-club-39095" title="Home Club">Home Club</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/casamona-international-real-estate-49875" title="Casamona (International Real Estate)">Casamona (International Real Estate)</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/real-estate-property-53917" title="Real Estate Property">Real Estate Property</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/beres-rent-59409" title="Beres Rent">Beres Rent</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/atipika-lifestyle-properties-59979" title="ATIPIKA Lifestyle Properties">ATIPIKA Lifestyle Properties</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/invest-properties-bcn-67020" title="INVEST PROPERTIES BCN">INVEST PROPERTIES BCN</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/ab-apartment-barcelona-36664" title="AB Apartment Barcelona">AB Apartment Barcelona</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/oak-properties-36164" title="Oak Properties">Oak Properties</a>,
#  <a class="real-estate-panel__title prevent" href="/inmobiliarias/rs-group-real-estate-32232" title="RS GROUP REAL ESTATE">RS GROUP REAL ESTATE</a>,
#  <a href="/inmobiliarias/barcelona">Ver todas las inmobiliarias en Barcelona</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-2">2</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-3">3</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-4">4</a>,
#  <a class="d-none--small-mobile" href="/alquiler/pisos/barcelona/pag-5">5</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-baratos">Pisos baratos de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-de-bancos">Pisos de bancos de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-lujo">Pisos de lujo de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-particulares">Pisos de particulares de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-terraza">Pisos con terraza de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-piscina">Pisos con piscina de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-garaje">Pisos con garaje de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-jardin">Pisos con jardín de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-amueblado">Pisos amueblados de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-balcon">Pisos con balcón de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/f-calefaccion">Pisos con calefacción de alquiler</a>,
#  <a class="pointer" href="/alquiler/pisos/barcelona/e-obra-nueva">Pisos de obra nueva de alquiler</a>,
#  <a href="https://www.yaencontre.com/inmuebles/venta/pisos/e-de-bancos">Pisos de bancos</a>,
#  <a href="/alquiler/pisos">Alquiler de pisos</a>,
#  <a href="/alquiler/casas">casas</a>,
#  <a href="/venta/pisos">Compra de pisos</a>,
#  <a href="/venta/casas">casas</a>,
#  <a class="icon-facebook" href="https://www.facebook.com/yaencontre.comvivienda/" rel="noopener noreferrer" target="_blank" title="Síguenos en Facebook"><span>Síguenos en Facebook</span></a>,
#  <a class="icon-instagram" href="https://www.instagram.com/yaencontre/" rel="noopener noreferrer" target="_blank" title="Síguenos en Instagram"><span>Síguenos en Instagram</span></a>,
#  <a class="icon-twitter" href="https://twitter.com/yaencontre" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en X"><span>Noticias inmobiliarias en X</span></a>,
#  <a class="icon-youtube-round" href="https://www.youtube.com/user/yaencontre/" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en Youtube"><span>Noticias inmobiliarias en Youtube</span></a>,
#  <a class="icon-linkedin" href="https://es.linkedin.com/company/grupo-yaencontre-com" rel="noopener noreferrer" target="_blank" title="Síguenos en Linkedin"><span>Síguenos en Linkedin</span></a>,
#  <a class="icon-tiktok" href="https://www.tiktok.com/@yaencontre.com" rel="noopener noreferrer" target="_blank" title="Síguenos en TikTok"><span>Síguenos en TikTok</span></a>,
#  <a href="https://www.yaencontre.com/vender-piso" target="_blank">Particulares</a>,
#  <a href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>,
#  <a href="https://www.yaencontre.com/grupo/contacta" target="_blank">Contactar</a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all("a")
for a in all_a[:5]:
    print(a)
    print(type(a))
# Out:
# <a class="icon-logo" href="/"></a>
# <class 'bs4.element.Tag'>
# <a class="classPublishAdvise text-default-color" href="/poner-anuncio" target="_blank"><span>PUBLICAR</span> anuncio</a>
# <class 'bs4.element.Tag'>
# <a class="classPublishAdvise text-default-color d-none--tablet" href="https://localgest.yaencontre.com/" rel="nofollow" target="_blank">Profesionales</a>
# <class 'bs4.element.Tag'>
# <a class="d-none--tablet" href="/">yaencontre</a>
# <class 'bs4.element.Tag'>
# <a class="link" href="/alquiler/pisos/barcelona-provincia">Barcelona (provincia)</a>
# <class 'bs4.element.Tag'>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 42 pisos con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - Títulos
# - Url
# - habitaciones
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %%
soup.find_all('a',attrs={'rel' : 'noopener noreferrer'})
# Out:
# [<a class="icon-facebook" href="https://www.facebook.com/yaencontre.comvivienda/" rel="noopener noreferrer" target="_blank" title="Síguenos en Facebook"><span>Síguenos en Facebook</span></a>,
#  <a class="icon-instagram" href="https://www.instagram.com/yaencontre/" rel="noopener noreferrer" target="_blank" title="Síguenos en Instagram"><span>Síguenos en Instagram</span></a>,
#  <a class="icon-twitter" href="https://twitter.com/yaencontre" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en X"><span>Noticias inmobiliarias en X</span></a>,
#  <a class="icon-youtube-round" href="https://www.youtube.com/user/yaencontre/" rel="noopener noreferrer" target="_blank" title="Noticias inmobiliarias en Youtube"><span>Noticias inmobiliarias en Youtube</span></a>,
#  <a class="icon-linkedin" href="https://es.linkedin.com/company/grupo-yaencontre-com" rel="noopener noreferrer" target="_blank" title="Síguenos en Linkedin"><span>Síguenos en Linkedin</span></a>,
#  <a class="icon-tiktok" href="https://www.tiktok.com/@yaencontre.com" rel="noopener noreferrer" target="_blank" title="Síguenos en TikTok"><span>Síguenos en TikTok</span></a>]

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los títulos de los pisos (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un piso y elegimos inspeccionar)

# %%
all_h3 = soup.find_all("h3")
for h3 in all_h3[:5]:
    print(h3)
    print('Es un objeto',str(type(h3)), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print()
    print('Todo el texto del h3')
    print(h3.get_text())
    print('--------------------------------------------------')
# Out:
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96822843" title="Piso en El Camp de l'Arpa del Clot, Barcelona">Piso en El Camp de l'Arpa del Clot, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.560 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en El Camp de l'Arpa del Clot, Barcelona2.560 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-29126-96352122" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.190 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona2.190 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-u8178150_37224251" title="Piso en calle Formatgeria, El Gòtic, Barcelona">Piso en calle Formatgeria, El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">825 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en calle Formatgeria, El Gòtic, Barcelona825 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60288-99803422" title="Ático en El Gòtic, Barcelona">Ático en El Gòtic, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">2.200 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Ático en El Gòtic, Barcelona2.200 €
# --------------------------------------------------
# <h3 class="title logo-aside"><a class="d-ellipsis" href="/alquiler/piso/inmueble-60085-100265982" title="Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona">Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona</a><div class="price-wrapper inline-flex logo-aside"><span class="price">5.000 €</span></div></h3>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del h3
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona5.000 €
# --------------------------------------------------

# %% [markdown]
# Si queremos obtener solo los títulos

# %%
all_h3 = soup.find_all('h3', class_='title')
for h3 in all_h3:
    print('Solo el título')
    print(h3.a.get_text(strip = True))
    print('Es un objeto',str(type(h3.a)), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print('---------------------------------------------------------------------')
# Out:
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Formatgeria, El Gòtic, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Gòtic, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - La Bonanova, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en El Camp de l'Arpa del Clot, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en El Gòtic, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en L'Antiga Esquerra de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Sants, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle De Balboa, La Barceloneta, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en L'Antiga Esquerra de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en calle De Viladomat, Sant Antoni, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en La Dreta de l'Eixample, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------
# Solo el título
# Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
# ---------------------------------------------------------------------

# %% [markdown]
# ### Los añadimos a una lista

# %%
lista_pisos=[]
all_h3 = soup.find_all('h3', class_='title')
for h3 in all_h3:
    lista_pisos.append(h3.a.get_text(strip = True))
lista_pisos
# Out:
# ["Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en calle Formatgeria, El Gòtic, Barcelona',
#  'Ático en El Gòtic, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  "Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Ático en El Gòtic, Barcelona',
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sants, Barcelona',
#  'Piso en calle De Balboa, La Barceloneta, Barcelona',
#  'Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  'Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona',
#  'Piso en calle De Viladomat, Sant Antoni, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona']

# %% [markdown]
# ##### Otra forma de hacerlo

# %%
lista_pisos=[]
all_h3 = soup.find_all('h3', attrs={'class':'title'})
for h3 in all_h3:
    lista_pisos.append(h3.a.get_text(strip = True))
lista_pisos
# Out:
# ["Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en calle Formatgeria, El Gòtic, Barcelona',
#  'Ático en El Gòtic, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  'Piso en Sant Gervasi - La Bonanova, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  "Piso en El Camp de l'Arpa del Clot, Barcelona",
#  'Ático en El Gòtic, Barcelona',
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Sant Gervasi - Galvany, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Sant Pere, Santa Caterina i la Ribera, Barcelona',
#  'Piso en Sants, Barcelona',
#  'Piso en calle De Balboa, La Barceloneta, Barcelona',
#  'Piso en calle De Les Escoles Pies, Sant Gervasi - Galvany, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  "Piso en L'Antiga Esquerra de l'Eixample, Barcelona",
#  'Piso en calle Avenir, Sant Gervasi - Galvany, Barcelona',
#  'Piso en calle De Viladomat, Sant Antoni, Barcelona',
#  "Piso en La Dreta de l'Eixample, Barcelona",
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en paseo De Garcia Fària, Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Piso en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona',
#  'Ático en Diagonal Mar i el Front Marítim del Poblenou, Barcelona']

# %% [markdown]
# ## Tips importantes

# %% [markdown]
# soup.find_all(“h3”) encuentra cada elemento h3 en la página web; con class_=”title” especificamos que buscamos específicamente etiquetas h3 que contengan el atributo class_=”title” (nota importante: el “_” en **class__=”title”** no es un error tipográfico, se requiere en Beautiful Soup cuando seleccionando atributos de clase).

# %% [markdown]
# Guardamos los elementos h3 en all_h3, que se comporta como una lista, por lo que podemos recorrerlos con un bucle for. En cada iteración extraemos solo el texto del elemento h3 con .get_text(), y con el parámetro strip=True nos aseguramos de eliminar cualquier espacio en blanco innecesario.

# %% [markdown]
# ## Obtener los METROS CUADRADOS

# %%
m2 = soup.find_all("div", class_="icon-meter")
lista_m2 = []
for i in m2:
    lista_m2.append(i.get_text(strip=True))
lista_m2
# Out:
# ['69 m²',
#  '80 m²',
#  '45 m²',
#  '109 m²',
#  '150 m²',
#  '130 m²',
#  '102 m²',
#  '221 m²',
#  '110 m²',
#  '85 m²',
#  '63 m²',
#  '115 m²',
#  '63 m²',
#  '50 m²',
#  '123 m²',
#  '123 m²',
#  '91 m²',
#  '91 m²',
#  '122 m²',
#  '119 m²',
#  '99 m²',
#  '97 m²',
#  '135 m²',
#  '79 m²',
#  '70 m²',
#  '56 m²',
#  '66 m²',
#  '226 m²',
#  '258 m²',
#  '102 m²',
#  '52 m²',
#  '80 m²',
#  '146 m²',
#  '146 m²',
#  '200 m²',
#  '200 m²',
#  '210 m²',
#  '130 m²',
#  '315 m²',
#  '133 m²',
#  '153 m²',
#  '157 m²']

# %% [markdown]
# Otra forma de hacerlo

# %% [markdown]
# #### Las dos listas contienen el mismo número de valores. Lo comprobamos

# %%
# Out:
# 42
# 42

# %% [markdown]
# #### Entonces, ya podríamos crear un DataFrame con títulos y metros cuadrados. Vamos a hacerlo

# %% [markdown]
# #### Primera forma de hacerlo

# %%
df_pisos = pd.DataFrame({"Titulo":lista_pisos,"m²":lista_m2})
df_pisos
# Out:
#                                                Titulo      m²
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona   69 m²
# 1   Piso en Sant Pere, Santa Caterina i la Ribera,...   80 m²
# 2      Piso en calle Formatgeria, El Gòtic, Barcelona   45 m²
# 3                        Ático en El Gòtic, Barcelona  109 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,
m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...            95 m²
# 5                      Estudio en El Raval, Barcelona            43 m²
# 6             Piso en El Putxet i el Farró, Barcelona            45 m²
# 7                         Piso en El Raval, Barcelona            45 m²
# 8   Piso en Diagonal Mar i el Front Marítim del Po...           155 m²
# 9   Piso en La Nova Esquerra de l'Eixample, Barcelona            82 m²
# 10  Piso en El Poble Sec - Parc de Montjuïc, Barce...            54 m²
# 11  Ático en L'Antiga Esquerra de l'Eixample, Barc...            78 m²
# 12  Dúplex en Sant Pere, Santa Caterina i la Riber...            70 m²
# 13  Piso en L'Antiga Esquerra de l'Eixample, Barce...            76 m²
# 14                 Ático en Vila de Gràcia, Barcelona            60 m²
# 15                  Piso en Vila de Gràcia, Barcelona            95 m²
# 16                        Piso en La Salut, Barcelona            67 m²
# 17              Piso en La Sagrada Família, Barcelona            70 m²
# 18          Piso en La Dreta de l'Eixample, Barcelona            80 m²
# 19  Piso en Diagonal Mar i el Front Marítim del Po...           200 m²
# 20          Piso en La Dreta de l'Eixample, Barcelona           106 m²
# 21          Piso en La Dreta de l'Eixample, Barcelona           180 m²
# 22  Piso en La Nova Esquerra de l'Eixample, Barcelona            77 m²
# 23                  Piso en Vila de Gràcia, Barcelona            90 m²
# 24                           Piso en Sants, Barcelona            52 m²
# 25                  Dúplex en La Teixonera, Barcelona           180 m²
# 26                 Ático en Vila de Gràcia, Barcelona            66 m²
# 27  Piso en Sant Pere, Santa Caterina i la Ribera,...            70 m²
# 28          Piso en La Dreta de l'Eixample, Barcelona           120 m²
# 29                  Piso en Vila de Gràcia, Barcelona           170 m²
# 30                  Piso en Vila de Gràcia, Barcelona            80 m²
# 31          Piso en La Dreta de l'Eixample, Barcelona            85 m²
# 32                  Piso en Vila de Gràcia, Barcelona            65 m²
# 33              Piso en La Sagrada Família, Barcelona            70 m²
# 34                     Piso en Sant Antoni, Barcelona            53 m²
# 35  Ático en L'Antiga Esquerra de l'Eixample, Barc...            71 m²
# 36                      Piso en Sant Martí, Barcelona            75 m²
# 37                Dúplex en Vila de Gràcia, Barcelona           114 m²
# 38                  Piso en Vila de Gràcia, Barcelona            60 m²
# 39                  Piso en Vila de Gràcia, Barcelona            42 m²
# 40  Ático en La Nova Esquerra de l'Eixample, Barce...            56 m²
# 41  Piso en L'Antiga Esquerra de l'Eixample, Barce...            70 m²

# %% [markdown]
# ## Obtener el número de habitaciones de cada inmueble

# %%
habs = soup.find_all("div", class_="icon-room")
lista_habs = []
for i in habs:
    lista_habs.append(i.get_text(strip=True))
len(lista_habs)
# Out:
# 42

# %% [markdown]
# ### Puede darse el caso de que un alojamiento no muestre el número de habitaciones. Las longitudes de las listas de títulos y habitaciones no encajarían...¿Cómo solventamos el problema?

# %% [markdown]
# Primera forma

# %%
group = soup.find_all("div", class_="iconGroup")
lista_h = []
for i in group:
    if i.find('div', class_='icon-room'):
        lista_h.append(i.find('div', class_='icon-room').get_text(strip=True))
    else:
        lista_h.append("No veo habitaciones")
lista_h
# Out:
# ['2 habs.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '2 habs.',
#  '3 habs.',
#  '2 habs.',
#  '3 habs.',
#  '3 habs.',
#  '2 habs.',
#  '1 hab.',
#  '4 habs.',
#  '2 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '2 habs.',
#  '2 habs.',
#  '2 habs.',
#  '2 habs.',
#  '4 habs.',
#  '5 habs.',
#  '3 habs.',
#  '1 hab.',
#  '2 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.']

# %% [markdown]
# Segunda forma

# %%
contenedor = soup.find_all('div', class_='iconGroup')
lista_h = []
for i in contenedor:
    try:
        lista_h.append(i.find('div', class_='icon-room').get_text())
    except:
        lista_h.append('No hay habitaciones')

lista_h
# Out:
# ['2 habs.',
#  '1 hab.',
#  '1 hab.',
#  '1 hab.',
#  '2 habs.',
#  '3 habs.',
#  '2 habs.',
#  '3 habs.',
#  '3 habs.',
#  '2 habs.',
#  '1 hab.',
#  '4 habs.',
#  '2 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '2 habs.',
#  '2 habs.',
#  '2 habs.',
#  '2 habs.',
#  '4 habs.',
#  '5 habs.',
#  '3 habs.',
#  '1 hab.',
#  '2 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '3 habs.',
#  '1 hab.',
#  '3 habs.',
#  '3 habs.']

# %% [markdown]
# ### Los añadimos a una lista

# %%
len(lista_h)
# Out:
# 42

# %% [markdown]
# ## Encontrar elementos por su selector CSS

# %%
rooms = soup.select('div.iconGroup div.icon-room span')
#Esto corresponde al selector CSS

# %%
for i in rooms:
    print(type(i))
    print(i.get_text())
# Out:
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 4 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 4 habs.
# <class 'bs4.element.Tag'>
# 5 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 2 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 1 hab.
# <class 'bs4.element.Tag'>
# 3 habs.
# <class 'bs4.element.Tag'>
# 3 habs.

# %% [markdown]
# ## Obtener los precios (find_all + get_text)

# %%
precios = soup.find_all('span', class_='price')
lista_precios = []
for precio in precios:
    lista_precios.append(precio.get_text(strip=True))
lista_precios
# Out:
# ['2.560 €',
#  '2.190 €',
#  '825 €',
#  '2.200 €',
#  '5.000 €',
#  '3.341 €',
#  '2.763 €',
#  '7.500 €',
#  '2.310 €',
#  '2.250 €',
#  '1.850 €',
#  '2.300 €',
#  '4.550 €',
#  '3.000 €',
#  '2.800 €',
#  '2.850 €',
#  '2.650 €',
#  '2.500 €',
#  '2.800 €',
#  '2.750 €',
#  '2.950 €',
#  '2.550 €',
#  '2.950 €',
#  '1.850 €',
#  '1.350 €',
#  '1.800 €',
#  '2.500 €',
#  '4.500 €',
#  '13.000 €',
#  '2.950 €',
#  '2.500 €',
#  '2.000 €',
#  '4.490 €',
#  '4.000 €',
#  '7.500 €',
#  '10.000 €',
#  '7.000 €',
#  '3.800 €',
#  '8.000 €',
#  '5.000 €',
#  '6.000 €',
#  '6.000 €']

# %% [markdown]
# ### Pero, en un DataFrame, te interesa tener el precio comprendido como un número int o float, para poder jugar con él. ¿Cómo lo haríamos?

# %%
precios = soup.find_all('span', class_='price')
for precio in precios:
    print(type(precio.get_text()))
    print(precio.get_text(strip=True).replace('.',''))
    print(precio.get_text(strip=True).replace('.','').split())
    print(precio.get_text(strip=True).replace('.','').split()[0])
    print('De momento es un string, así que lo pasamos a float')
    print(float(precio.get_text(strip=True).replace('.','').split()[0]))
    print('---------------------------------------------------------------')
# Out:
# <class 'str'>
# 2560 €
# ['2560', '€']
# 2560
# De momento es un string, así que lo pasamos a float
# 2560.0
# ---------------------------------------------------------------
# <class 'str'>
# 2190 €
# ['2190', '€']
# 2190
# De momento es un string, así que lo pasamos a float
# 2190.0
# ---------------------------------------------------------------
# <class 'str'>
# 825 €
# ['825', '€']
# 825
# De momento es un string, así que lo pasamos a float
# 825.0
# ---------------------------------------------------------------
# <class 'str'>
# 2200 €
# ['2200', '€']
# 2200
# De momento es un string, así que lo pasamos a float
# 2200.0
# ---------------------------------------------------------------
# <class 'str'>
# 5000 €
# ['5000', '€']
# 5000
# De momento es un string, así que lo pasamos a float
# 5000.0
# ---------------------------------------------------------------
# <class 'str'>
# 3341 €
# ['3341', '€']
# 3341
# De momento es un string, así que lo pasamos a float
# 3341.0
# ---------------------------------------------------------------
# <class 'str'>
# 2763 €
# ['2763', '€']
# 2763
# De momento es un string, así que lo pasamos a float
# 2763.0
# ---------------------------------------------------------------
# <class 'str'>
# 7500 €
# ['7500', '€']
# 7500
# De momento es un string, así que lo pasamos a float
# 7500.0
# ---------------------------------------------------------------
# <class 'str'>
# 2310 €
# ['2310', '€']
# 2310
# De momento es un string, así que lo pasamos a float
# 2310.0
# ---------------------------------------------------------------
# <class 'str'>
# 2250 €
# ['2250', '€']
# 2250
# De momento es un string, así que lo pasamos a float
# 2250.0
# ---------------------------------------------------------------
# <class 'str'>
# 1850 €
# ['1850', '€']
# 1850
# De momento es un string, así que lo pasamos a float
# 1850.0
# ---------------------------------------------------------------
# <class 'str'>
# 2300 €
# ['2300', '€']
# 2300
# De momento es un string, así que lo pasamos a float
# 2300.0
# ---------------------------------------------------------------
# <class 'str'>
# 4550 €
# ['4550', '€']
# 4550
# De momento es un string, así que lo pasamos a float
# 4550.0
# ---------------------------------------------------------------
# <class 'str'>
# 3000 €
# ['3000', '€']
# 3000
# De momento es un string, así que lo pasamos a float
# 3000.0
# ---------------------------------------------------------------
# <class 'str'>
# 2800 €
# ['2800', '€']
# 2800
# De momento es un string, así que lo pasamos a float
# 2800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2850 €
# ['2850', '€']
# 2850
# De momento es un string, así que lo pasamos a float
# 2850.0
# ---------------------------------------------------------------
# <class 'str'>
# 2650 €
# ['2650', '€']
# 2650
# De momento es un string, así que lo pasamos a float
# 2650.0
# ---------------------------------------------------------------
# <class 'str'>
# 2500 €
# ['2500', '€']
# 2500
# De momento es un string, así que lo pasamos a float
# 2500.0
# ---------------------------------------------------------------
# <class 'str'>
# 2800 €
# ['2800', '€']
# 2800
# De momento es un string, así que lo pasamos a float
# 2800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2750 €
# ['2750', '€']
# 2750
# De momento es un string, así que lo pasamos a float
# 2750.0
# ---------------------------------------------------------------
# <class 'str'>
# 2950 €
# ['2950', '€']
# 2950
# De momento es un string, así que lo pasamos a float
# 2950.0
# ---------------------------------------------------------------
# <class 'str'>
# 2550 €
# ['2550', '€']
# 2550
# De momento es un string, así que lo pasamos a float
# 2550.0
# ---------------------------------------------------------------
# <class 'str'>
# 2950 €
# ['2950', '€']
# 2950
# De momento es un string, así que lo pasamos a float
# 2950.0
# ---------------------------------------------------------------
# <class 'str'>
# 1850 €
# ['1850', '€']
# 1850
# De momento es un string, así que lo pasamos a float
# 1850.0
# ---------------------------------------------------------------
# <class 'str'>
# 1350 €
# ['1350', '€']
# 1350
# De momento es un string, así que lo pasamos a float
# 1350.0
# ---------------------------------------------------------------
# <class 'str'>
# 1800 €
# ['1800', '€']
# 1800
# De momento es un string, así que lo pasamos a float
# 1800.0
# ---------------------------------------------------------------
# <class 'str'>
# 2500 €
# ['2500', '€']
# 2500
# De momento es un string, así que lo pasamos a float
# 2500.0
# ---------------------------------------------------------------
# <class 'str'>
# 4500 €
# ['4500', '€']
# 4500
# De momento es un string, así que lo pasamos a float
# 4500.0
# ---------------------------------------------------------------
# <class 'str'>
# 13000 €
# ['13000', '€']
# 13000
# De momento es un string, así que lo pasamos a float
# 13000.0
# ---------------------------------------------------------------
# <class 'str'>
# 2950 €
# ['2950', '€']
# 2950
# De momento es un string, así que lo pasamos a float
# 2950.0
# ---------------------------------------------------------------
# <class 'str'>
# 2500 €
# ['2500', '€']
# 2500
# De momento es un string, así que lo pasamos a float
# 2500.0
# ---------------------------------------------------------------
# <class 'str'>
# 2000 €
# ['2000', '€']
# 2000
# De momento es un string, así que lo pasamos a float
# 2000.0
# ---------------------------------------------------------------
# <class 'str'>
# 4490 €
# ['4490', '€']
# 4490
# De momento es un string, así que lo pasamos a float
# 4490.0
# ---------------------------------------------------------------
# <class 'str'>
# 4000 €
# ['4000', '€']
# 4000
# De momento es un string, así que lo pasamos a float
# 4000.0
# ---------------------------------------------------------------
# <class 'str'>
# 7500 €
# ['7500', '€']
# 7500
# De momento es un string, así que lo pasamos a float
# 7500.0
# ---------------------------------------------------------------
# <class 'str'>
# 10000 €
# ['10000', '€']
# 10000
# De momento es un string, así que lo pasamos a float
# 10000.0
# ---------------------------------------------------------------
# <class 'str'>
# 7000 €
# ['7000', '€']
# 7000
# De momento es un string, así que lo pasamos a float
# 7000.0
# ---------------------------------------------------------------
# <class 'str'>
# 3800 €
# ['3800', '€']
# 3800
# De momento es un string, así que lo pasamos a float
# 3800.0
# ---------------------------------------------------------------
# <class 'str'>
# 8000 €
# ['8000', '€']
# 8000
# De momento es un string, así que lo pasamos a float
# 8000.0
# ---------------------------------------------------------------
# <class 'str'>
# 5000 €
# ['5000', '€']
# 5000
# De momento es un string, así que lo pasamos a float
# 5000.0
# ---------------------------------------------------------------
# <class 'str'>
# 6000 €
# ['6000', '€']
# 6000
# De momento es un string, así que lo pasamos a float
# 6000.0
# ---------------------------------------------------------------
# <class 'str'>
# 6000 €
# ['6000', '€']
# 6000
# De momento es un string, así que lo pasamos a float
# 6000.0
# ---------------------------------------------------------------

# %% [markdown]
# #### Los añadimos a una lista

# %%
precios = soup.find_all('span', class_='price')
lista_precios = []
for precio in precios:
    lista_precios.append(float(precio.get_text(strip=True).replace('.','').split()[0]))
lista_precios
# Out:
# [2560.0,
#  2190.0,
#  825.0,
#  2200.0,
#  5000.0,
#  3341.0,
#  2763.0,
#  7500.0,
#  2310.0,
#  2250.0,
#  1850.0,
#  2300.0,
#  4550.0,
#  3000.0,
#  2800.0,
#  2850.0,
#  2650.0,
#  2500.0,
#  2800.0,
#  2750.0,
#  2950.0,
#  2550.0,
#  2950.0,
#  1850.0,
#  1350.0,
#  1800.0,
#  2500.0,
#  4500.0,
#  13000.0,
#  2950.0,
#  2500.0,
#  2000.0,
#  4490.0,
#  4000.0,
#  7500.0,
#  10000.0,
#  7000.0,
#  3800.0,
#  8000.0,
#  5000.0,
#  6000.0,
#  6000.0]

# %% [markdown]
# ### Forma un poco más pro de hacerlo: list comprehension

# %%
lista_precios = [float(precio.get_text(strip=True).replace('.','').split()[0]) for precio in precios]

# %% [markdown]
# ### Podéis también meterlo en una serie o en un dataframe

# %%
# Out:
# 42

# %% [markdown]
# ### Podéis también meterlo en una serie o en un dataframe

# %%
lista_df = []
for i in range(len(lista_pisos)):
    data = {'Título': lista_pisos[i],
            'Metros cuadrados': lista_m2[i],
            'Habitaciones': lista_h[i],
            'Precios': lista_precios[i]}
    lista_df.append(data)
df = pd.DataFrame(lista_df)
df
# Out:
#                                                Título Metros cuadrados  \
# 0       Piso en El Camp de l'Arpa del Clot, Barcelona            69 m²
# 1   Piso en Sant Pere, Santa Caterina i la Ribera,...            80 m²
# 2      Piso en calle Formatgeria, El Gòtic, Barcelona            45 m²
# 3                        Ático en El Gòtic, Barcelona           109 m²
# 4   Piso en Sant Pere, Santa Caterina i la Ribera,...           150 m²
# 5       Piso en Sant Gervasi - La Bonanova, Barcelona           130 m²
# 6       Piso en Sant Gervasi - La Bonanova, Barcelona           102 m²
# 7           Piso en La Dreta de l'Eixample, Barcelona           221 m²
# 8           Piso en Sant Gervasi - Galvany, Barcelona           110 m²
# 9       Piso en El Camp de l'Arpa del Clot, Barcelona            85 m²
# 10                       Ático en El Gòtic, Barcelona            63 m²
# 11  Piso en L'Antiga Esquerra de l'Eixample, Barce...           115 m²
# 12          Piso en La Dreta de l'Eixample, Barcelona            63 m²
# 13          Piso en La Dreta de l'Eixample, Barcelona            50 m²
# 14          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 15          Piso en Sant Gervasi - Galvany, Barcelona           123 m²
# 16          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 17          Piso en Sant Gervasi - Galvany, Barcelona            91 m²
# 18          Piso en Sant Gervasi - Galvany, Barcelona           122 m²
# 19          Piso en Sant Gervasi - Galvany, Barcelona           119 m²
# 20          Piso en Sant Gervasi - Galvany, Barcelona            99 m²
# 21          Piso en Sant Gervasi - Galvany, Barcelona            97 m²
# 22          Piso en Sant Gervasi - Galvany, Barcelona           135 m²
# 23  Piso en Diagonal Mar i el Front Marítim del Po...            79 m²
# 24  Piso en Sant Pere, Santa Caterina i la Ribera,...            70 m²
# 25                           Piso en Sants, Barcelona            56 m²
# 26  Piso en calle De Balboa, La Barceloneta, Barce...            66 m²
# 27  Piso en calle De Les Escoles Pies, Sant Gervas...           226 m²
# 28          Piso en La Dreta de l'Eixample, Barcelona           258 m²
# 29  Piso en L'Antiga Esquerra de l'Eixample, Barce...           102 m²
# 30  Piso en calle Avenir, Sant Gervasi - Galvany, ...            52 m²
# 31  Piso en calle De Viladomat, Sant Antoni, Barce...            80 m²
# 32          Piso en La Dreta de l'Eixample, Barcelona           146 m²
# 33  Piso en Diagonal Mar i el Front Marítim del Po...           146 m²
# 34  Ático en Diagonal Mar i el Front Marítim del P...           200 m²
# 35  Ático en paseo De Garcia Fària, Diagonal Mar i...           200 m²
# 36  Ático en Diagonal Mar i el Front Marítim del P...           210 m²
# 37  Piso en Diagonal Mar i el Front Marítim del Po...           130 m²
# 38  Piso en Diagonal Mar i el Front Marítim del Po...           315 m²
# 39  Piso en Diagonal Mar i el Front Marítim del Po...           133 m²
# 40  Ático en Diagonal Mar i el Front Marítim del P...           153 m²
# 41  Ático en Diagonal Mar i el Front Marítim del P...           157 m²
#
#    Habitaciones  Precios
# 0       2 habs.   2560.0
# 1        1 hab.   2190.0
# 2        1 hab.    825.0
# 3        1 hab.   2200.0
# 4       2 habs.   5000.0
# 5       3 habs.   3341.0
# 6       2 habs.   2763.0
# 7       3 habs.   7500.0
# 8       3 habs.   2310.0
# 9       2 habs.   2250.0
# 10       1 hab.   1850.0
# 11      4 habs.   2300.0
# 12      2 habs.   4550.0
# 13       1 hab.   3000.0
# 14      3 habs.   2800.0
# 15      3 habs.   2850.0
# 16      3 habs.   2650.0
# 17      3 habs.   2500.0
# 18      3 habs.   2800.0
# 19      3 habs.   2750.0
# 20      3 habs.   2950.0
# 21      3 habs.   2550.0
# 22      3 habs.   2950.0
# 23      2 habs.   1850.0
# 24      2 habs.   1350.0
# 25      2 habs.   1800.0
# 26      2 habs.   2500.0
# 27      4 habs.   4500.0
# 28      5 habs.  13000.0
# 29      3 habs.   2950.0
# 30       1 hab.   2500.0
# 31      2 habs.   2000.0
# 32      3 habs.   4490.0
# 33      3 habs.   4000.0
# 34      3 habs.   7500.0
# 35      3 habs.  10000.0
# 36      3 habs.   7000.0
# 37      3 habs.   3800.0
# 38      3 habs.   8000.0
# 39       1 hab.   5000.0
# 40      3 habs.   6000.0
# 41      3 habs.   6000.0

# %%
# Out:
#                                                Título Metros cuadrados  \
# 2                       Piso en Fort Pienc, Barcelona           110 m²
# 3   Piso en L'Antiga Esquerra de l'Eixample, Barce...           131 m²
# 8   Piso en Diagonal Mar i el Front Marítim del Po...           155 m²
# 9   Piso en La Nova Esquerra de l'Eixample, Barcelona            82 m²
# 11  Ático en L'Antiga Esquerra de l'Eixample, Barc...            78 m²
# 13  Piso en L'Antiga Esquerra de l'Eixample, Barce...            76 m²
# 14                 Ático en Vila de Gràcia, Barcelona            60 m²
# 15                  Piso en Vila de Gràcia, Barcelona            95 m²
# 17              Piso en La Sagrada Família, Barcelona            70 m²
# 18          Piso en La Dreta de l'Eixample, Barcelona            80 m²
# 19  Piso en Diagonal Mar i el Front Marítim del Po...           200 m²
# 20          Piso en La Dreta de l'Eixample, Barcelona           106 m²
# 21          Piso en La Dreta de l'Eixample, Barcelona           180 m²
# 23                  Piso en Vila de Gràcia, Barcelona            90 m²
# 25                  Dúplex en La Teixonera, Barcelona           180 m²
# 26                 Ático en Vila de Gràcia, Barcelona            66 m²
# 27  Piso en Sant Pere, Santa Caterina i la Ribera,...            70 m²
# 28          Piso en La Dreta de l'Eixample, Barcelona           120 m²
# 29                  Piso en Vila de Gràcia, Barcelona           170 m²
# 30                  Piso en Vila de Gràcia, Barcelona            80 m²
# 32                  Piso en Vila de Gràcia, Barcelona            65 m²
# 33              Piso en La Sagrada Família, Barcelona            70 m²
# 37                Dúplex en Vila de Gràcia, Barcelona           114 m²
# 38                  Piso en Vila de Gràcia, Barcelona            60 m²
# 41  Piso en L'Antiga Esquerra de l'Eixample, Barce...            70 m²
#
#    Habitaciones  Precios
# 2       3 habs.   3250.0
# 3       3 habs.   3600.0
# 8       3 habs.   3700.0
# 9       3 habs.   3000.0
# 11       1 hab.   3000.0
# 13      2 habs.   2800.0
# 14      2 habs.   3400.0
# 15      2 habs.   2650.0
# 17      2 habs.   2650.0
# 18      2 habs.   2650.0
# 19      3 habs.   8000.0
# 20      2 habs.   4100.0
# 21      5 habs.   5000.0
# 23      2 habs.   2750.0
# 25      5 habs.   2800.0
# 26       1 hab.   3200.0
# 27       1 hab.   2750.0
# 28      2 habs.   2950.0
# 29      2 habs.   3750.0
# 30      2 habs.   3200.0
# 32      2 habs.   2950.0
# 33      2 habs.   2650.0
# 37      3 habs.   3850.0
# 38      2 habs.   2700.0
# 41      2 habs.   3000.0

# %% [markdown]
# ### Conseguir los teléfonos de las inmobiliarias

# %%
tlf = soup.find_all('div', class_='icon-phone-2')
lista_tlf = []
for i in tlf:
    try:
        lista_tlf.append(int(i.span.get_text(strip=True).replace(' ','')))
    except:
        lista_tlf.append("No hay tlf")
lista_tlf
# Out:
# [936178845,
#  936178845,
#  'No hay tlf',
#  936175122,
#  936179214,
#  936178487,
#  936176098,
#  936172495,
#  936175082,
#  936170336,
#  936176241,
#  936176020,
#  936174047,
#  936178046,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936179793,
#  936175459,
#  936175459,
#  936174964,
#  936177625,
#  936178609,
#  936179931,
#  936177625,
#  936179914,
#  936173581,
#  936179737,
#  936173040,
#  936173040,
#  936173040,
#  936173040,
#  936173040,
#  936173040,
#  936173040,
#  936173040,
#  936173040]

# %% [markdown]
# ## Obtener URLs de alojamientos

# %%
url_principal = 'https://www.yaencontre.com'

lista_pisos = []

pisos = soup.find_all('h3', class_='title')
for piso in pisos:
    lista_pisos.append()

# %% [markdown]
# Entramos en cada url

# %%
for url in lista_pisos:
    response = requests.get(url)
    soup_piso = bs(response)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# #### De cada alojamiento obtener:
# * Ubicación
# * Si tiene o no tiene Aire acondicionado
# * Si está amueblado o no.

# %% [markdown]
# ### Ubicación

# %%
# Out:
# El Poble Sec - Parc de Montjuïc, Sants - Montjuïc, Barcelona
# Sant Gervasi - Galvany, Sarrià - Sant Gervasi, Barcelona
# Fort Pienc, Eixample, Barcelona
# L'Antiga Esquerra de l'Eixample, Eixample, Barcelona
# Sant Pere, Santa Caterina i la Ribera, Ciutat Vella, Barcelona
# El Raval, Ciutat Vella, Barcelona
# El Putxet i el Farró, Sarrià - Sant Gervasi, Barcelona
# El Raval, Ciutat Vella, Barcelona
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona
# La Nova Esquerra de l'Eixample, Eixample, Barcelona
# El Poble Sec - Parc de Montjuïc, Sants - Montjuïc, Barcelona
# L'Antiga Esquerra de l'Eixample, Eixample, Barcelona
# Sant Pere, Santa Caterina i la Ribera, Ciutat Vella, Barcelona
# L'Antiga Esquerra de l'Eixample, Eixample, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# La Salut, Gràcia, Barcelona
# La Sagrada Família, Eixample, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# Diagonal Mar i el Front Marítim del Poblenou, Sant Martí, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# La Nova Esquerra de l'Eixample, Eixample, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Sants, Sants - Montjuïc, Barcelona
# La Teixonera, Horta - Guinardó, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Sant Pere, Santa Caterina i la Ribera, Ciutat Vella, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# La Dreta de l'Eixample, Eixample, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# La Sagrada Família, Eixample, Barcelona
# Sant Antoni, Eixample, Barcelona
# L'Antiga Esquerra de l'Eixample, Eixample, Barcelona
# Sant Martí, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# Vila de Gràcia, Gràcia, Barcelona
# La Nova Esquerra de l'Eixample, Eixample, Barcelona
# L'Antiga Esquerra de l'Eixample, Eixample, Barcelona

# %% [markdown]
# ### Aire acondicionado

# %%
# Out:
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# No tiene
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado
# Sí tiene aire acondicionado

# %% [markdown]
# ### Amueblado

# %%
# Out:
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# Sí
# No
# Sí
# Sí
# Sí
# Sí
# Sí

# %% [markdown]
# ---

# %% [markdown]
# ## Ahora vamos a scrapear todos los pisos, yendo de página en página

# %%
url = "https://www.yaencontre.com/alquiler/pisos/barcelona"
# Out:
# Página 1
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-1
# /alquiler/piso/inmueble-55533-AT2106015-A
# /alquiler/piso/inmueble-55533-AT2202021-A
# /alquiler/piso/inmueble-56196-BINGIN-A
# /alquiler/piso/inmueble-56196-AMAZZER-A
# /alquiler/piso/inmueble-55533-AT1915012-A
# /alquiler/piso/inmueble-55533-AT1912019-A
# /alquiler/piso/inmueble-60247-6ae0e66293d017ac001d-A
# /alquiler/piso/inmueble-55533-AT2103004-A
# /alquiler/piso/inmueble-55652-BCNR33308-A
# /alquiler/piso/inmueble-56196-KUFRA-A
# /alquiler/piso/inmueble-55533-AT2006031-A
# /alquiler/piso/inmueble-56196-ATACAMA-A
# /alquiler/piso/inmueble-56196-THAR-A
# /alquiler/piso/inmueble-56196-LEGE-A
# /alquiler/piso/inmueble-56196-HASSI-A
# /alquiler/piso/inmueble-56196-AMANDI-A
# /alquiler/piso/inmueble-51707-Travessera_Views-A
# /alquiler/piso/inmueble-56196-SIERRA-A
# /alquiler/piso/inmueble-56196-DAMAR-A
# /alquiler/piso/inmueble-54754-ARMGFM01-A
# /alquiler/piso/inmueble-56196-SUMBAWA-A
# /alquiler/piso/inmueble-55856-10783-A
# /alquiler/piso/inmueble-59409-BAU-00354-A
# /alquiler/piso/inmueble-56196-PUMORI-A
# /alquiler/piso/inmueble-54965-AMT-MEL11-A
# /alquiler/piso/inmueble-56248-Marhort-A
# /alquiler/piso/inmueble-56196-BINTAN-A
# /alquiler/piso/inmueble-56196-NOVA-A
# /alquiler/piso/inmueble-56196-KUTA-A
# /alquiler/piso/inmueble-56196-PASIR-A
# /alquiler/piso/inmueble-56196-MALANG-A
# /alquiler/piso/inmueble-54965-AMT-RON41A-A
# /alquiler/piso/inmueble-56196-OETUNE-A
# /alquiler/piso/inmueble-56196-SAVANNAH-A
# /alquiler/piso/inmueble-55533-AT2111036-A
# /alquiler/piso/inmueble-59409-b-355-A
# /alquiler/piso/inmueble-55115-93751463-A
# /alquiler/piso/inmueble-56196-AMAZONAS-A
# /alquiler/piso/inmueble-56196-MOJO-A
# /alquiler/piso/inmueble-56196-FAYA-A
# /alquiler/piso/inmueble-59409-b1255-A
# /alquiler/piso/inmueble-56196-TAMBO-A
# Página 2
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-2
# /alquiler/piso/inmueble-50866-1675-A
# /alquiler/piso/inmueble-55533-AT2103029-A
# /alquiler/piso/inmueble-56196-SONORA-A
# /alquiler/piso/inmueble-59409-b-0041-A
# /alquiler/piso/inmueble-55652-BCNR6285-A
# /alquiler/piso/inmueble-50866-3721-A
# /alquiler/piso/inmueble-55274-HARBOUR_PRESTIGE-A
# /alquiler/piso/inmueble-55533-AT2202010-A
# /alquiler/piso/inmueble-55533-AT2112008-A
# /alquiler/piso/inmueble-56196-KARMA-A
# /alquiler/piso/inmueble-54754-ARG002-A
# /alquiler/piso/inmueble-59409-b-1337-A
# /alquiler/piso/inmueble-55274-RAMBLA_CATALUNYA_EXCELLENCE-A
# /alquiler/piso/inmueble-59409-Bau-001151-A
# /alquiler/piso/inmueble-54754-ARM109-A
# /alquiler/piso/inmueble-59409-b-1561-A
# /alquiler/piso/inmueble-59409-b1299-A
# /alquiler/piso/inmueble-52174-100950-A
# /alquiler/piso/inmueble-56738-A-DM001-A
# /alquiler/piso/inmueble-29126-96822843
# /alquiler/piso/inmueble-54754-ARM0091-A
# /alquiler/piso/inmueble-59086-Promo-1-96629243
# /alquiler/piso/inmueble-54754-ARG004-A
# /alquiler/piso/inmueble-51958-BCN12217A-A
# /alquiler/piso/inmueble-60097-509919-A
# /alquiler/piso/inmueble-56196-BATAM-A
# /alquiler/piso/inmueble-55652-BCNR32932-A
# /alquiler/piso/inmueble-59409-Bau-00585-A
# /alquiler/piso/inmueble-56196-NEMA-A
# /alquiler/piso/inmueble-29126-96352122
# /alquiler/piso/inmueble-55652-BCNR32483-A
# /alquiler/piso/inmueble-54754-ARMGFAT01-A
# /alquiler/piso/inmueble-55533-AT1906035-A
# /alquiler/piso/inmueble-54965-AMT-RON12A-A
# /alquiler/piso/inmueble-32385-7254218-AL
# /alquiler/piso/inmueble-51958-BCN12337A-A
# /alquiler/piso/inmueble-59409-b-1250-A
# /alquiler/piso/inmueble-55533-AT1906042-A
# /alquiler/piso/inmueble-55115-Fluvia-A
# /alquiler/piso/inmueble-59409-b-1114-A
# /alquiler/piso/inmueble-55533-AT2103024-A
# /alquiler/piso/inmueble-55533-AT1908013-A
# Página 3
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-3
# /alquiler/piso/inmueble-56196-TALAT-A
# /alquiler/piso/inmueble-55533-AT1908015-A
# /alquiler/piso/inmueble-54976-tmrdt-A
# /alquiler/piso/inmueble-51958-BCN12343A-A
# /alquiler/piso/inmueble-56814-CCAS2-A
# /alquiler/piso/inmueble-60247-1c83b2312bc6306c15d5-A
# /alquiler/piso/inmueble-55533-AT1908011-A
# /alquiler/piso/inmueble-56673-AGNBmt6-A
# /alquiler/piso/inmueble-59409-Bau-00931-A
# /alquiler/piso/inmueble-54965-AMT-RON12B-A
# /alquiler/piso/inmueble-59409-b-1478-A
# /alquiler/piso/inmueble-55533-AT1906043-A
# /alquiler/piso/inmueble-55533-AT2011018-A
# /alquiler/piso/inmueble-55533-AT1908014-A
# /alquiler/piso/inmueble-56196-SHOKAI-A
# /alquiler/piso/inmueble-55392-PG21A025-PISO-A
# /alquiler/piso/inmueble-59409-b1274-A
# /alquiler/piso/inmueble-59409-Bau-00787-A
# /alquiler/piso/inmueble-60247-9533c0726d470f88619a-A
# /alquiler/piso/inmueble-55533-AT2011015-A
# /alquiler/piso/inmueble-59409-Bau-00734-A
# /alquiler/piso/inmueble-55533-AT1906039-A
# /alquiler/piso/inmueble-55533-AT1906037-A
# /alquiler/piso/inmueble-55274-CALVELL_C51-A
# /alquiler/piso/inmueble-56814-CCONS5-A
# /alquiler/piso/inmueble-55652-BCNR19407-A
# /alquiler/piso/inmueble-56814-CCONS11-A
# /alquiler/piso/inmueble-56196-SANDE-A
# /alquiler/piso/inmueble-55533-AT1912002-A
# /alquiler/piso/inmueble-60247-3ca547bec15dfd00a438-A
# /alquiler/piso/inmueble-60247-b845f43e82ef9642f7b2-A
# /alquiler/piso/inmueble-59409-b-1178-A
# /alquiler/piso/inmueble-56196-WABI-A
# /alquiler/piso/inmueble-60247-2c39138d36f3eae51400-A
# /alquiler/piso/inmueble-54965-AMT-MEL21-A
# /alquiler/piso/inmueble-55533-AT1909002-A
# /alquiler/piso/inmueble-56217-94585850-A
# /alquiler/piso/inmueble-60247-ad9cac8396738c0477cf-A
# /alquiler/piso/inmueble-60247-f8e5a220aa502c9ebfd2-A
# /alquiler/piso/inmueble-59409-b-1562-A
# /alquiler/piso/inmueble-60247-99406a4dddd7dc606dca-A
# /alquiler/piso/inmueble-54965-AMT-MELB2-A
# Página 4
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-4
# /alquiler/piso/inmueble-55533-AT1908012-A
# /alquiler/piso/inmueble-55274-PASSEIG_CALVELL_A24-A
# /alquiler/piso/inmueble-55533-AT1906036-A
# /alquiler/piso/inmueble-9585-Tiradors_Duplex-A
# /alquiler/piso/inmueble-56814-CCONS4-A
# /alquiler/piso/inmueble-60247-d61b9091ad77dfb8d592-A
# /alquiler/piso/inmueble-60247-604e37ef26538efcdf7e-A
# /alquiler/piso/inmueble-60247-4ebe6f4bcd24343a739b-A
# /alquiler/piso/inmueble-56814-CSANTS1-A
# /alquiler/piso/inmueble-56217-93129608-A
# /alquiler/piso/inmueble-54965-AMT-RON41B-A
# /alquiler/piso/inmueble-60247-a04f7ea82b25f0a9400a-A
# /alquiler/piso/inmueble-60247-88285ea9b507d10a1277-A
# /alquiler/piso/inmueble-60247-be1fb001873ebe39c96e-A
# /alquiler/piso/inmueble-60247-f23190e69123574dc818-A
# /alquiler/piso/inmueble-60223-497-A
# /alquiler/piso/inmueble-60247-3add6d43ff52f3f0bdfb-A
# /alquiler/piso/inmueble-60247-242270c257201bbb600b-A
# /alquiler/piso/inmueble-60247-786593afed8d4fc369eb-A
# /alquiler/piso/inmueble-60247-9ccee9a0727bae9b92bd-A
# /alquiler/piso/inmueble-60247-54c39c7eb26e8b480669-A
# /alquiler/piso/inmueble-51707-Gran_Via_Universitat-A
# /alquiler/piso/inmueble-60247-c36c323fdf9d3ba88d95-A
# /alquiler/piso/inmueble-60283-A-2989-A
# /alquiler/piso/inmueble-60247-948dc8cb80a68c0f6214-A
# /alquiler/piso/inmueble-56217-93129453-A
# /alquiler/piso/inmueble-60247-acc483da5b170cd5a248-A
# /alquiler/piso/inmueble-60247-45380351b59ee0f73775-A
# /alquiler/piso/inmueble-55856-9558-A
# /alquiler/piso/inmueble-60247-d53087a3a02a84fb4392-A
# /alquiler/piso/inmueble-60247-0cd8bb4635dcea571bce-A
# /alquiler/piso/inmueble-60247-65130a74d2d11a4da951-A
# /alquiler/piso/inmueble-60247-ae64907c016ae0932958-A
# /alquiler/piso/inmueble-60247-132151c44b1acd455a01-A
# /alquiler/piso/inmueble-60247-0fcb21ccae81008744ba-A
# /alquiler/piso/inmueble-60247-b0fc0347246af0bc7634-A
# /alquiler/piso/inmueble-60247-18d0bc839f54d4594b86-A
# /alquiler/piso/inmueble-60247-25f692bbfca3aed9755b-A
# /alquiler/piso/inmueble-56217-93129396-A
# /alquiler/piso/inmueble-60247-f5dedac07a3e01aefb46-A
# /alquiler/piso/inmueble-60247-5646e9acd90779e6b7a2-A
# /alquiler/piso/inmueble-60247-1097d4bbb903746618bc-A
# Página 5
# https://www.yaencontre.com/alquiler/pisos/barcelona/pag-5

# %%
# Out:
# Página 1
# Página 2
# Página 3
# Página 4
# Página 5
# Página 6
# Página 7
# Página 8
# Página 9
# Página 10
# Página 11
# Página 12
# Página 13
# Página 14
# Página 15
# Página 16
# Página 17
# Página 18
# Página 19

# %%
# Out:
# ['https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2106015-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2202021-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-BINGIN-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-AMAZZER-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1915012-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1912019-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60247-6ae0e66293d017ac001d-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2103004-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR33308-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-KUFRA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2006031-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-ATACAMA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-THAR-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LEGE-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-HASSI-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-AMANDI-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51707-Travessera_Views-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-SIERRA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-DAMAR-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARMGFM01-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-SUMBAWA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55856-10783-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-BAU-00354-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-PUMORI-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54965-AMT-MEL11-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56248-Marhort-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-BINTAN-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-NOVA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-KUTA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-PASIR-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-MALANG-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54965-AMT-RON41A-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-OETUNE-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-SAVANNAH-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2111036-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-355-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55115-93751463-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-AMAZONAS-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-MOJO-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-FAYA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b1255-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-TAMBO-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-50866-1675-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2103029-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-SONORA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-0041-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR6285-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-50866-3721-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55274-HARBOUR_PRESTIGE-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2202010-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2112008-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-KARMA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARG002-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1337-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55274-RAMBLA_CATALUNYA_EXCELLENCE-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-Bau-001151-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARM109-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1561-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b1299-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-52174-100950-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56738-A-DM001-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-29126-96822843',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARM0091-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59086-Promo-1-96629243',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARG004-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51958-BCN12217A-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60097-509919-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-BATAM-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR32932-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-Bau-00585-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-NEMA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-29126-96352122',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR32483-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54754-ARMGFAT01-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1906035-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54965-AMT-RON12A-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-32385-7254218-AL',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51958-BCN12337A-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1250-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1906042-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55115-Fluvia-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1114-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2103024-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1908013-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-TALAT-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT1908015-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54976-tmrdt-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51958-BCN12343A-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56814-CCAS2-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60247

#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LODJA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-HUELMA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-GERANIO-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-JAIZ-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-FURORE-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64417-101811068',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-20627-101866233',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60409-101858381-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-36929-101678086',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1408-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59409-b-1655-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56124-101859612',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60180-101692733',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LENDU-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LULUA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-SIWA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53776-97900366',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LUGROS-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56493-101783842',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-54803-101820936',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-50164-101849524-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-36678-98379665',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60515-101870669',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56391-A4865-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56377-FMA-B23943_1-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-BAWAH-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-MONTORO-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-REMY-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53776-90736778',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-LUIZA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-ROVIRA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-5373-96937608',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53661-101389017',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR41341-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55856-11626-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-62292-BCN-78-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55761-101874366-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53541-C-101-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60515-101575450',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55860-101859220',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-23260-101677003',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56436-98775076',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-36413-101661464',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55274-VILA_DE_GRACIA_SUITES_1-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60515-101602868',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53420-101867684',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-TAIGA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56196-AGEROLA-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-60261-076_003_-_Deu_i_Mata_154_-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-101098575',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-90620799',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-37638264',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-81237364',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-101605085',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-100093844',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-89993811',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-88633466',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-36890967',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-101128496',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-81397052',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-92987496',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-94840251',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64057-101665490',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64057-101462318',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-88616758',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-91625214',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-89743296',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-101586060',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-89710807',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64057-101676810',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64057-101733071',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-89742933',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-92138405',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-88640346',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56942-81236274',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53420-101438325',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-52174-101430-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2208017-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2304033-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55533-AT2205011-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55302-101876973',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55136-101654015',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-50260-101886246',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55569-99200002',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR42742-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55652-BCNR8781-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59900-7542-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-101754604',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-101811255',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-89913819',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-100739095',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-100410171',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-101815007',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51565-93485813',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-46589-95878709',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101741631',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101811194',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101437582',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101452099',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101552326',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101550713',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101441659',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-66360-101811195',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56302-99969246',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56328-92220170',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56678-101894933',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56864-APS26-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-64057-101894743',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56572-IB40270B-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-56572-IB40270-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-47696-101894997',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59339-101478241',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59339-100842209',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59339-101823819',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59339-101667054',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55007-89410875',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55007-1241725',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55216-101729691',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-55225-32215065',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-51028-94700041',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59794-88043332',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-48960-37437255',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-59936-J-2284-A',
#  'https://www.yaencontre.com/alquiler/piso/inmueble-53072-ZZM28225-A']

# %%
contador = 1

lista_titulos = []
lista_ubicaciones = []
lista_precios = []
lista_precios_antes = []
lista_habitaciones = []
lista_bathrooms = []
lista_m2 = [] 
lista_aire = [] #aire acondicionado
lista_amueblado =[] #si lo está o no
lista_armarios_empotrados = [] #sí o no
lista_ascensor = []
lista_balcon = []
lista_calefaccion =[]
lista_terraza = []
lista_caracteristicas = []
lista_descripcion = []

for url_alquiler in lista_urls:
    response = requests.get(url_alquiler)
    soup_url = bs(response.content, 'lxml')

    try:
        lista_titulos.append(soup_url.find('h1', class_='details-title').get_text(strip=True))
    except:
        lista_titulos.append('No veo el título')

    try:
        lista_ubicaciones.append(soup_url.find('div',class_= 'details-address').get_text(strip=True))
    except:
        lista_ubicaciones.append('No encuentro la ubicación')

    try:
        lista_precios.append(soup_url.find('span',class_='price').get_text(strip=True))
    except:
        lista_precios.append('No veo el precio')

    try:
        lista_precios_antes.append(soup_url.find('span', class_='icon-text previousPriceText').get_text(strip=True))
    except:
        try:
            lista_precios_antes.append(soup_url.find('span',class_='price').get_text(strip=True))
        except:
            lista_precios_antes.append('No veo el precio')
    
    try:
        lista_habitaciones.append(soup_url.find('div',class_='icon-room').get_text(strip=True))
    except:
        lista_habitaciones.append('No veo las habitaciones')

    try:
        lista_bathrooms.append(soup_url.find('div', class_='icon-bath').get_text(strip=True))
    except:
        lista_bathrooms.append('No encuentro los baños')
    
    try:
        lista_m2.append(soup_url.find('div', class_='icon-meter').get_text(strip=True))
    except:
        lista_m2.append('No encuentro los baños')
    
    try:
        if soup_url.find('div', class_='icon-airConditioning').get_text(strip=True) == '':
            lista_aire.append('Sí')
        else:
            lista_aire.append('No')
    except:
        lista_aire.append('No')
    
    try:
        if soup_url.find('div', class_='icon-furnished').get_text(strip=True) == '':
            lista_amueblado.append('Sí')
        else:
            lista_amueblado.append('No')
    except:
        lista_amueblado.append('No')

    try:
        if soup_url.find('div', class_='icon-builtInWardrobes').get_text(strip=True) == '':
            lista_armarios_empotrados.append('Sí')
        else:
            lista_armarios_empotrados.append('No')
    except:
        lista_armarios_empotrados.append('No')
    
    try:
        if soup_url.find('div', class_='icon-lift').get_text(strip=True) == '':
            lista_ascensor.append('Sí')
        else:
            lista_ascensor.append('No')
    except:
        lista_ascensor.append('No')

    try:
        if soup_url.find('div', class_='icon-balcony').get_text(strip=True) == '':
            lista_balcon.append('Sí')
        else:
            lista_balcon.append('No')
    except:
        lista_balcon.append('No')

    try:
        if soup_url.find('div', class_='icon-centralHeating').get_text(strip=True) == '':
            lista_calefaccion.append('Sí')
        else:
            lista_calefaccion.append('No')
    except:
        lista_calefaccion.append('No')

    try:
        if soup_url.find('div', class_='icon-terrace').get_text(strip=True) == '':
            lista_terraza.append('Sí')
        else:
            lista_terraza.append('No')
    except:
        lista_terraza.append('No')

    try:
        lista_caracteristicas.append([i.get_text(strip=True) for i in soup_url.find_all('li', class_='feature')])
    except:
        lista_caracteristicas.append('No veo más características')

    try:
        lista_descripcion.append(soup_url.find('div', class_='description').get_text(strip=True))
    except:
        lista_descripcion.append('No veo la descripción')

    print('Url: '+str(contador))

    contador +=1
# Out:
# Url: 1
# Url: 2
# Url: 3
# Url: 4
# Url: 5
# Url: 6
# Url: 7
# Url: 8
# Url: 9
# Url: 10
# Url: 11
# Url: 12
# Url: 13
# Url: 14
# Url: 15
# Url: 16
# Url: 17
# Url: 18
# Url: 19
# Url: 20
# Url: 21
# Url: 22
# Url: 23
# Url: 24
# Url: 25
# Url: 26
# Url: 27
# Url: 28
# Url: 29
# Url: 30
# Url: 31
# Url: 32
# Url: 33
# Url: 34
# Url: 35
# Url: 36
# Url: 37
# Url: 38
# Url: 39
# Url: 40
# Url: 41
# Url: 42
# Url: 43
# Url: 44
# Url: 45
# Url: 46
# Url: 47
# Url: 48
# Url: 49
# Url: 50
# Url: 51
# Url: 52
# Url: 53
# Url: 54
# Url: 55
# Url: 56
# Url: 57
# Url: 58
# Url: 59
# Url: 60
# Url: 61
# Url: 62
# Url: 63
# Url: 64
# Url: 65
# Url: 66
# Url: 67
# Url: 68
# Url: 69
# Url: 70
# Url: 71
# Url: 72
# Url: 73
# Url: 74
# Url: 75
# Url: 76
# Url: 77
# Url: 78
# Url: 744
# Url: 745
# Url: 746
# Url: 747
# Url: 748
# Url: 749
# Url: 750
# Url: 751
# Url: 752
# Url: 753
# Url: 754
# Url: 755
# Url: 756
# Url: 757
# Url: 758
# Url: 759
# Url: 760
# Url: 761
# Url: 762
# Url: 763
# Url: 764
# Url: 765
# Url: 766
# Url: 767
# Url: 768
# Url: 769
# Url: 770
# Url: 771
# Url: 772
# Url: 773
# Url: 774
# Url: 775
# Url: 776
# Url: 777
# Url: 778
# Url: 779
# Url: 780
# Url: 781
# Url: 782
# Url: 783
# Url: 784
# Url: 785
# Url: 786
# Url: 787
# Url: 788
# Url: 789
# Url: 790
# Url: 791
# Url: 792
# Url: 793
# Url: 794
# Url: 795
# Url: 796
# Url: 797
# Url: 798

# %% [markdown]
# ### Creamos el DataFrame

# %%
lista_df = []

for i in range(len(lista_precios)):
    data = {'Url': lista_urls[i],
            'Título': lista_titulos[i],
            'Ubicación': lista_ubicaciones[i],
            'Precio': lista_precios[i],
            'Precio Antes': lista_precios_antes[i],
            'Habitaciones': lista_habitaciones[i],
            'Baños':lista_bathrooms[i],
            'Metros cuadrados': lista_m2[i],
            'Aire acondicionado': lista_aire[i],
            'Amueblado': lista_amueblado[i],
            'Armarios empotrados': lista_armarios_empotrados[i],
            'Ascensor': lista_ascensor[i],
            'Balcón': lista_balcon[i],
            'Calefacción': lista_calefaccion[i],
            'Terraza': lista_terraza[i],
            'Características': lista_caracteristicas[i],
            'Descripción': lista_descripcion[i]
            }
    
    lista_df.append(data)

df = pd.DataFrame(lista_df)

# %%
df
# Out:
#                                                    Url  \
# 0    https://www.yaencontre.com/alquiler/piso/inmue...
# 1    https://www.yaencontre.com/alquiler/piso/inmue...
# 2    https://www.yaencontre.com/alquiler/piso/inmue...
# 3    https://www.yaencontre.com/alquiler/piso/inmue...
# 4    https://www.yaencontre.com/alquiler/piso/inmue...
# ..                                                 ...
# 793  https://www.yaencontre.com/alquiler/piso/inmue...
# 794  https://www.yaencontre.com/alquiler/piso/inmue...
# 795  https://www.yaencontre.com/alquiler/piso/inmue...
# 796  https://www.yaencontre.com/alquiler/piso/inmue...
# 797  https://www.yaencontre.com/alquiler/piso/inmue...
#
#                                                 Título  \
# 0    Alquiler de ático en El Poble Sec - Parc de Mo...
# 1    Piso en alquiler en Sant Gervasi - Galvany de ...
# 2    Piso en alquiler en Fort Pienc de 3 habitacion...
# 3    Piso en alquiler en L'Antiga Esquerra de l'Eix...
# 4    Alquiler de piso en Sant Pere, Santa Caterina ...
# ..                                                 ...
# 793  Piso en alquiler en Sant Gervasi - Galvany de ...
# 794  Piso en alquiler en L'Antiga Esquerra de l'Eix...
# 795  Ático en alquiler en Fort Pienc de 3 habitacio...
# 796  Piso en alquiler en El Gòtic de 4 habitaciones...
# 797  Ático en alquiler en La Nova Esquerra de l'Eix...
#
#                                              Ubicación   Precio Precio Antes  \
# 0    El Poble Sec - Parc de Montjuïc, Sants - Montj...  1.485 €      1.485 €
# 1    Sant Gervasi - Galvany, Sarrià - Sant Gervasi,...  1.995 €      2.095 €
# 2                      Fort Pienc, Eixample, Barcelona  3.250 €      3.250 €
# 3    L'Antiga Esquerra de l'Eixample, Eixample, Bar...  3.600 €      3.600 €
# 4    Sant Pere, Santa Caterina i la Ribera, Ciutat ...  2.350 €      2.350 €
# ..                                                 ...      ...          ...
# 793  Sant Gervasi - Galvany, Sarrià - Sant Gervasi,...  3.400 €      3.400 €
# 794  L'Antiga Esquerra de l'Eixample, Eixample, Bar...  1.790 €      1.790 €
# 795                    Fort Pienc, Eixample, Barcelona  2.490 €      2.500 €
# 796                  El Gòtic, Ciutat Vella, Barcelona  2.150 €      2.150 €
# 797  La Nova Esquerra de l'Eixample, Eixample, Barc...  2.300 €      2.300 €
#
#     Habitaciones Baños Metros cuadrados Aire acondicionado Amueblado  \
# 0              1     1            60 m²                 No        Sí
# 1              2     2            85 m²                 Sí        Sí
# 2              3     2           110 m²                 Sí        Sí
# 3              3     2           131 m²                 Sí        Sí
# 4              3     2            95 m²                 Sí        Sí
# ..           ...   ...              ...                ...       ...
# 793            4     3           287 m²                 Sí        Sí
# 794            3     2            87 m²                 Sí        Sí
# 795            3     2           176 m²                 Sí        Sí
# 796            4     2           155 m²                 Sí        No
# 797            3     2            90 m²                 No        Sí
#
#     Armarios empotrados Ascensor Balcón Calefacción Terraza  \
# 0                    No       Sí     No          Sí      Sí
# 1                    No       Sí     No          Sí      No
# 2                    Sí       Sí     Sí          Sí      Sí
# 3                    Sí       Sí     Sí          Sí      No
# 4                    No       No     Sí          Sí      No
# ..                  ...      ...    ...         ...     ...
# 793                  Sí       Sí     No          Sí      Sí
# 794                  Sí       Sí     Sí          Sí      Sí
# 795                  Sí       Sí     No          Sí      Sí
# 796                  No       Sí     No          Sí      Sí
# 797                  Sí       Sí     Sí          Sí      Sí
#
#                                        Características  \
# 0    [Amueblado, Ascensor, Calefacción, Terraza, Es...
# 1    [Aire acondicionado, Amueblado, Ascensor, Cale...
# 2    [Aire acondicionado, Amueblado, Armarios empot...
# 3    [Aire acondicionado, Amueblado, Armarios empot...
# 4    [Aire acondicionado, Amueblado, Balcón, Calefa...
# ..                                                 ...
# 793  [Aire acondicionado, Amueblado, Armarios empot...
# 794  [Aire acondicionado, Amueblado, Armarios empot...
# 795  [Aire acondicionado, Amueblado, Armarios empot...
# 796  [Aire acondicionado, Ascensor, Calefacción, Te...
# 797  [Amueblado, Armarios empotrados, Ascensor, Bal...
#
#                                            Descripción
# 0    Apartamento de alquiler temporal (desde 32 día...
# 1    Apartamento de alquiler temporal (desde 32 día...
# 2    *COMPLETAMENTE AMUEBLADO*\n*ALQUILERES MENSUAL...
# 3    *COMPLETAMENTE AMUEBLADO*\n*ALQUILERES MENSUAL...
# 4    Apartamento de alquiler temporal (desde 32 día...
# ..                                                 ...
# 793  DISPONIBLE AGOSTO. Piso alto muy luminoso tota...
# 794  Alquiler VERANO JULIO. Contactanos por email. ...
# 795  Exclusivo ático con espectacular terraza con v...
# 796  En una preciosa y emblemática finca en un tran...
# 797  Zazume te trae esta amplio y acogedor ático co...
#
# [798 rows x 17 columns]
